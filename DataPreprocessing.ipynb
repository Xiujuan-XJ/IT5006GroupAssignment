# %%
import numpy as np
import pandas as pd
import os
from sklearn.feature_selection import VarianceThreshold

# %%
os.getcwd()
# Out:
# '/Users/xiujuan/Desktop/BMI MASTER/IT5006 Data Analytics/groupAssignment'

# %%
df=pd.read_csv('delet_row_missing2.csv',index_col=0)
df=df.drop(['Unnamed: 0'], axis=1)
df.replace('PrivacySuppressed', np.nan,inplace=True)
# replace all 'PrivacySuppressed' to np.nan
# Out:
# /var/folders/w7/_4x8q4gx5m9bhtzk0c7gy40c0000gn/T/ipykernel_4418/2356052068.py:1: DtypeWarning: Columns (612,626,668,669,673,684,688,689,690,704,718,732,746,795,796,804,805,806,818,819,820,821,863,866,871,872,873,874,875,876,877,878,879,880,881,882,935,936,937,938,939,950,951,952,953,954,958,972,974,1058,1065,1113,1114,1115,1116,1117,1191,1192,1193,1194,1195,1196,1197,1198,1199,1200,1201,1202,1203,1204,1205,1206,1435,1436,1568,1569,1570,1571,1580,1581,1582,1583,1812) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('delet_row_missing2.csv',index_col=0)

# %%
df.iloc[:,[612,626,668,669,673,684,688,689,690]]
# Out:
#      NONCOM_RPY_1YR_RT NONCOM_RPY_3YR_RT DEP_INC_PCT_LO IND_INC_PCT_LO  \
# 0          0.111891892       0.187003968    0.569139673    0.901587302
# 1          0.346713892       0.429033417      0.3487095    0.594202899
# 2          0.144208038       0.210772834            NaN            NaN
# 3          0.362745098       0.420181969     0.26901566    0.688851914
# 4           0.10538201       0.177339902    0.577628635    0.921933086
# ...                ...               ...            ...            ...
# 4375               NaN               NaN            NaN            NaN
# 4376               NaN               NaN            NaN            NaN
# 4377               NaN               NaN            NaN            NaN
# 4378               NaN               NaN            NaN            NaN
# 4379               NaN               NaN            NaN            NaN
#
#        INC_PCT_H1 APPL_SCH_PCT_GE4 OVERALL_YR2_N LO_INC_YR2_N MD_INC_YR2_N
# ...

# %%
df.shape
# Out:
# (4380, 1841)

# %%
df.head(3)
# Out:
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# 2  100690  2503400.0  25034.0                   Amridge University
#
#          CITY STABBR         ZIP  \
# 0      Normal     AL       35762
# 1  Birmingham     AL  35294-0110
# 2  Montgomery     AL  36117-3553
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
#
#                       INSTURL  \
# 0               www.aamu.edu/
# 1        https://www.uab.edu/
# 2  www.amridgeuniversity.edu/
#
#                                               NPCURL  ...  COUNT_WNE_MALE1_P8  \
# 0  www.aamu.edu/admissions-aid/tuition-fees/net-p...  ...               834.0
# ...

# %%
df.describe()
# Out:
#               UNITID         OPEID        OPEID6      SCH_DEG         HCM2  \
# count    4380.000000  4.380000e+03   4380.000000  4371.000000  4380.000000
# mean   252076.324886  1.371334e+06  12548.940639     2.073439     0.008676
# std    124165.981788  2.972025e+06  12727.005991     0.877826     0.092750
# min    100654.000000  1.002000e+05   1002.000000     1.000000     0.000000
# 25%    160627.750000  2.671030e+05   2670.750000     1.000000     0.000000
# 50%    205191.000000  6.385165e+05   6385.000000     2.000000     0.000000
# 75%    381292.750000  2.230851e+06  22213.500000     3.000000     0.000000
# max    493451.000000  8.209888e+07  42837.000000     3.000000     1.000000
#
#               MAIN    NUMBRANCH      PREDDEG      HIGHDEG      CONTROL  ...  \
# count  4380.000000  4380.000000  4380.000000  4380.000000  4380.000000  ...
# mean      0.829909     2.510046     2.070776     2.639498     1.944749  ...
# ...

# %%
df.describe(include='all')
# Out:
#                UNITID         OPEID        OPEID6             INSTNM  \
# count     4380.000000  4.380000e+03   4380.000000               4380
# unique            NaN           NaN           NaN               4304
# top               NaN           NaN           NaN  Cortiva Institute
# freq              NaN           NaN           NaN                  6
# mean    252076.324886  1.371334e+06  12548.940639                NaN
# std     124165.981788  2.972025e+06  12727.005991                NaN
# min     100654.000000  1.002000e+05   1002.000000                NaN
# 25%     160627.750000  2.671030e+05   2670.750000                NaN
# 50%     205191.000000  6.385165e+05   6385.000000                NaN
# 75%     381292.750000  2.230851e+06  22213.500000                NaN
# max     493451.000000  8.209888e+07  42837.000000                NaN
#
#             CITY STABBR    ZIP                ACCREDAGENCY          INSTURL  \
# ...

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %%
#check na, and there is 1403 columns has at least 60% of valid value
len(df.columns[np.where(df.isna().sum().apply(lambda x: (1-x/4380))>=0.6)])
# Out:
# 1403

# %%
#check na, and there is 1403 columns has at least 60% of valid value
len(df.columns[np.where(df.isna().sum().apply(lambda x: (1-x/4380))>=0.7)])
# Out:
# 1248

# %%
#check na, and there is 312 columns has at least 60% of valid value
len(df.columns[np.where(df.isna().sum().apply(lambda x: (1-x/4380))>=0.99)])
# Out:
# 312

# %%
#look at overall non-na percentage in each columns
df.isna().sum().apply(lambda x: (1-x/4380)).sort_values(ascending=False)
# Out:
# UNITID        1.000000
# CIP26ASSOC    1.000000
# CIP30CERT4    1.000000
# CIP30ASSOC    1.000000
# CIP30CERT2    1.000000
#                 ...
# MTHCMP6       0.091096
# CIPTITLE6     0.089498
# ACTWR75       0.066667
# ACTWR25       0.066667
# ACTWRMID      0.066667
# Length: 1841, dtype: float64

# %%
#after disucsson we decided to set threshold as 0.7 as our final dataset

# %%
# split dataset into accoridng to different level of missing values
df1=df.iloc[:,np.where(df.isna().sum().apply(lambda x: (1-x/4380))>=0.7)[0]]

# %%
df1.head()
# Out:
#    UNITID      OPEID   OPEID6                               INSTNM  \
# 0  100654   100200.0   1002.0             Alabama A & M University
# 1  100663   105200.0   1052.0  University of Alabama at Birmingham
# 2  100690  2503400.0  25034.0                   Amridge University
# 3  100706   105500.0   1055.0  University of Alabama in Huntsville
# 4  100724   100500.0   1005.0             Alabama State University
#
#          CITY STABBR         ZIP  \
# 0      Normal     AL       35762
# 1  Birmingham     AL  35294-0110
# 2  Montgomery     AL  36117-3553
# 3  Huntsville     AL       35899
# 4  Montgomery     AL  36104-0271
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
# 3  Southern Association of Colleges and Schools C...
# 4  Southern Association of Colleges and Schools C...
#
# ...

# %%
df1.describe(include='all')
# Out:
#                UNITID         OPEID        OPEID6             INSTNM  \
# count     4380.000000  4.380000e+03   4380.000000               4380
# unique            NaN           NaN           NaN               4304
# top               NaN           NaN           NaN  Cortiva Institute
# freq              NaN           NaN           NaN                  6
# mean    252076.324886  1.371334e+06  12548.940639                NaN
# std     124165.981788  2.972025e+06  12727.005991                NaN
# min     100654.000000  1.002000e+05   1002.000000                NaN
# 25%     160627.750000  2.671030e+05   2670.750000                NaN
# 50%     205191.000000  6.385165e+05   6385.000000                NaN
# 75%     381292.750000  2.230851e+06  22213.500000                NaN
# max     493451.000000  8.209888e+07  42837.000000                NaN
#
#             CITY STABBR    ZIP                ACCREDAGENCY          INSTURL  \
# ...

# %%
# numeric column
from sklearn.impute import SimpleImputer
num_col=df1.select_dtypes(include=['int64','float64'],exclude=['string'] )

# %%
num_col_index=num_col.columns

# %%
num_col.shape
# Out:
# (4380, 511)

# %%
num_col.to_csv('numeric_columns.csv',index=True)

# %%
num_col.head()
# Out:
#    UNITID      OPEID   OPEID6  SCH_DEG  HCM2  MAIN  NUMBRANCH  PREDDEG  \
# 0  100654   100200.0   1002.0      3.0     0     1          1        3
# 1  100663   105200.0   1052.0      3.0     0     1          1        3
# 2  100690  2503400.0  25034.0      3.0     0     1          1        2
# 3  100706   105500.0   1055.0      3.0     0     1          1        3
# 4  100724   100500.0   1005.0      3.0     0     1          1        3
#
#    HIGHDEG  CONTROL  ...  MD_EARN_WNE_MALE0_P8  COUNT_WNE_MALE1_P8  \
# 0        4        1  ...               32612.0               834.0
# 1        4        1  ...               41296.0              1233.0
# 2        4        2  ...               24940.0                78.0
# 3        4        1  ...               41189.0               891.0
# 4        4        1  ...               27573.0              1077.0
#
#    MD_EARN_WNE_MALE1_P8  GT_THRESHOLD_P10  MD_EARN_WNE_INC1_P10  \
# 0               36639.0            0.6044               34076.0
# ...

# %%
len(df_num_variance),len(df_num_variance[0])
# Out:
# (4380, 189)

# %% [markdown]
# ### 1.1 Select Nominal Data (numeric data representing category) using data dictionary

# %%
dic=pd.read_excel('CollegeScorecardDataDictionary.xlsx',sheet_name='Institution_Data_Dictionary')

# %%
dic=dic[['NAME OF DATA ELEMENT','dev-category','API data type','VARIABLE NAME','VALUE','LABEL','NOTES']]

# %%
dic.head(15)
# Out:
#                                  NAME OF DATA ELEMENT dev-category  \
# 0                             Unit ID for institution         root
# 1                      8-digit OPE ID for institution         root
# 2                      6-digit OPE ID for institution         root
# 3                                    Institution name       school
# 4                                                City       school
# 5                                      State postcode       school
# 6                                            ZIP code       school
# 7                          Accreditor for institution       school
# 8                      URL for institution's homepage       school
# 9          URL for institution's net price calculator       school
# 10     Predominant degree awarded (recoded 0s and 4s)       school
# 11  Schools that are on Heightened Cash Monitoring...       school
# 12                               Flag for main campus       school
# ...

# %%
dic.shape
# Out:
# (3251, 7)

# %%
dic_tofill=dic[['NAME OF DATA ELEMENT','VARIABLE NAME']].fillna(method="ffill")

# %%
dic_tofill
# Out:
#                                    NAME OF DATA ELEMENT  \
# 0                               Unit ID for institution
# 1                        8-digit OPE ID for institution
# 2                        6-digit OPE ID for institution
# 3                                      Institution name
# 4                                                  City
# ...                                                 ...
# 3246  Median earnings of students working and not en...
# 3247  Median earnings of independent students workin...
# 3248  Median earnings of dependent students working ...
# 3249  Median earnings of non-male students working a...
# 3250  Median earnings of male students working and n...
#
#                VARIABLE NAME
# 0                     UNITID
# 1                      OPEID
# 2                     OPEID6
# 3                     INSTNM
# 4                       CITY
# ...                      ...
# 3246    MD_EARN_WNE_INC3_P10
# 3247  MD_EARN_WNE_INDEP1_P10
# ...

# %%
dic1=dic.drop(columns=['NAME OF DATA ELEMENT','VARIABLE NAME','dev-category','API data type','NOTES'])

# %%
dic=pd.concat([dic_tofill,dic1],axis=1)

# %%
dic.head(30)
# Out:
#                                  NAME OF DATA ELEMENT VARIABLE NAME VALUE  \
# 0                             Unit ID for institution        UNITID   NaN
# 1                      8-digit OPE ID for institution         OPEID   NaN
# 2                      6-digit OPE ID for institution        OPEID6   NaN
# 3                                    Institution name        INSTNM   NaN
# 4                                                City          CITY   NaN
# 5                                      State postcode        STABBR   NaN
# 6                                            ZIP code           ZIP   NaN
# 7                          Accreditor for institution  ACCREDAGENCY   NaN
# 8                      URL for institution's homepage       INSTURL   NaN
# 9          URL for institution's net price calculator        NPCURL   NaN
# 10     Predominant degree awarded (recoded 0s and 4s)       SCH_DEG   NaN
# 11  Schools that are on Heightened Cash Monitoring...          HCM2   NaN
# ...

# %%
merged=pd.merge(pd.DataFrame(num_col.columns,columns=['VARIABLE NAME']),dic, on='VARIABLE NAME',how ='left')

# %%
grouped=merged.groupby(by=['VARIABLE NAME'],dropna=False,sort=False,as_index=False).agg({'VALUE':'nunique','LABEL':'unique'}).apply(lambda x:x).sort_values(by='VALUE',ascending=False)

# %%
grouped[grouped.VALUE>=1].to_csv('num_columns_categoricalvalue.csv',index=True)

# %%
grouped #if unique count is more than 1, then it will be categorical like following
# Out:
#              VARIABLE NAME  VALUE  \
# 10                 ST_FIPS     58
# 15                 CCBASIC     35
# 17                CCSIZSET     20
# 16                CCUGPROF     17
# 12                  LOCALE     12
# ..                     ...    ...
# 181             CIP39CERT2      0
# 180             CIP39CERT1      0
# 179             CIP38BACHL      0
# 178             CIP38CERT4      0
# 510  MD_EARN_WNE_MALE1_P10      0
#
#                                                  LABEL
# 10   [Alabama, Alaska, Arizona, Arkansas, Californi...
# 15   [Not applicable, (Not classified), Associate's...
# 17   [Not applicable, (Not classified), Two-year, v...
# 16   [Not applicable, Not classified (Exclusively G...
# 12   [City: Large (population of 250,000 or more), ...
# ..                                                 ...
# 181                                              [nan]
# 180                                              [nan]
# ...

# %% [raw]
# # NEXT, set aside nominal data
# for ordinal numeric data, we calculate vairance, remove low variant columns
# for nominal numeric data, we will decide from then on

# %% [markdown]
# ### 1.2 Variance

# %%
# set threshold as 0.8
selected = VarianceThreshold(threshold=(.8 * (1 - .8)))
df_num_variance=selected.fit_transform(num_col)

# %% [markdown]
# ### 1.3 pearson corr against target

# %%
def pearson_correlation(df,target_threshold,feature_threshold):
    #df=df.drop(columns='outcome')
    if target_threshold:
        target='outcome'
        corr=df.corr()
        candidates=corr.index[(corr[target].abs()>target_threshold)].values
        candidates=candidates[candidates!=target]
    else:
        corr=df.corr()
    #print('correlated to',target,': ',candidates)
    removed=[]
    for c1 in candidates:
        for c2 in candidates:
            if (c1 not in removed) and (c2 not in removed):
                if c1 !=c2:
                    coef=corr.loc[c1,c2]
                    if coef>(feature_threshold) or coef<(-feature_threshold):
                        print('coef between {} and {} :{}'.format(c1,c2,coef))
                        removed.append(c1)
    print('removed:', removed)
    return removed

# %% [markdown]
# ## 2. Missing Value

# %% [markdown]
# ## (DONT USE) 1. Missing Value (XJ's try)

# %%
num_col_index
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'SCH_DEG', 'HCM2', 'MAIN', 'NUMBRANCH',
#        'PREDDEG', 'HIGHDEG', 'CONTROL',
#        ...
#        'MD_EARN_WNE_MALE0_P8', 'COUNT_WNE_MALE1_P8', 'MD_EARN_WNE_MALE1_P8',
#        'GT_THRESHOLD_P10', 'MD_EARN_WNE_INC1_P10', 'MD_EARN_WNE_INC2_P10',
#        'MD_EARN_WNE_INDEP1_P10', 'MD_EARN_WNE_INDEP0_P10',
#        'MD_EARN_WNE_MALE0_P10', 'MD_EARN_WNE_MALE1_P10'],
#       dtype='object', length=511)

# %% [markdown]
# ### 1.1 missing value using mean

# %%
imp_mean= SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
num_col_imput_mean=imp_mean.fit_transform(num_col)

# %%
df_num_imp_mean=pd.DataFrame(num_col_imput_mean,columns=num_col_index)

# %%
len(df_num_mean_variance[0])
# Out:
# 188

# %%
df_num_mean_variance
# Out:
# array([[1.00654000e+05, 1.00200000e+05, 1.00200000e+03, ...,
#         3.54240000e+04, 3.60500000e+04, 3.63770000e+04],
#        [1.00663000e+05, 1.05200000e+05, 1.05200000e+03, ...,
#         4.64350000e+04, 4.20070000e+04, 5.61640000e+04],
#        [1.00690000e+05, 2.50340000e+06, 2.50340000e+04, ...,
#         4.12996170e+04, 3.23110000e+04, 4.95990000e+04],
#        ...,
#        [4.93080000e+05, 4.14430100e+06, 4.14430000e+04, ...,
#         4.12996170e+04, 3.75778770e+04, 4.79922813e+04],
#        [4.93132000e+05, 2.36200400e+06, 2.36200000e+04, ...,
#         5.17470000e+04, 4.51180000e+04, 5.12640000e+04],
#        [4.93451000e+05, 3.97040200e+06, 3.97040000e+04, ...,
#         2.83880000e+04, 2.57800000e+04, 4.79922813e+04]])

# %% [markdown]
# ### 1.2 missing value using median

# %%
imp_median= SimpleImputer(missing_values=np.nan, strategy='median')
num_col_imput_median=imp_median.fit_transform(num_col)

# %%
num_col_imput_median.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w7/_4x8q4gx5m9bhtzk0c7gy40c0000gn/T/ipykernel_4418/1789808093.py in <module>
# ----> 1 num_col_imput_median.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
corr=num_col.corr()
feature_threshold=0.5
removed=[]
for c1 in num_col.columns:
    for c2 in num_col.columns:
        if (c1 not in removed) and (c2 not in removed):
            if c1 !=c2:
                coef=corr.loc[c1,c2]
                if coef>(feature_threshold) or coef<(-feature_threshold):
                    print('coef between {} and {} :{}'.format(c1,c2,coef))
                    removed.append(c1)
# Out:
# coef between UNITID and OPEID6 :0.6654072262838182
# coef between OPEID and COUNT_WNE_P10 :0.7375452993453325
# coef between OPEID6 and SCH_DEG :-0.5529989481934982
# coef between SCH_DEG and PREDDEG :0.9461991587158912
# coef between NUMBRANCH and INC_N :0.5003895403070786
# coef between PREDDEG and HIGHDEG :0.8799777589890091
# coef between HIGHDEG and CCBASIC :0.8599347251976419
# coef between CONTROL and PCIP24 :-0.5039185107302699
# coef between REGION and LONGITUDE :-0.6412469722650977
# coef between CCBASIC and CCUGPROF :0.8282477595208636
# coef between CCUGPROF and CCSIZSET :0.8786567126664757
# coef between CCSIZSET and PCIP26 :0.50894725396458
# coef between TRIBAL and UGDS_AIAN :0.917780097842444
# coef between AANAPII and UGDS_ASIAN :0.5002319545979933
# coef between HSI and UGDS_HISP :0.5366007064641216
# coef between PCIP12 and CIP12CERT1 :0.5926558188132222
# coef between PCIP13 and CIP13BACHL :0.508419070475846
# ...

# %%
len(removed)
# Out:
# 332
